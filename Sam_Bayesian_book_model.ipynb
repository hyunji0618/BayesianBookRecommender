# %%
#import pytensor
#print(pytensor.config.cxx)

#set up g++ and openBLAS

#import pytensor
#print(dir(pytensor.config))

#import pytensor
#pytensor.config.blas__ldflags = '-LC:\\OpenBLAS\\lib -lopenblas'
#print(pytensor.config.blas__ldflags)

#import pytensor
#print("BLAS flags:", pytensor.config.blas__ldflags)
# print("Computation Mode:", pytensor.config.mode)

# %%
np.__version__
# Out:
# '1.26.4'

# %%
# pip install openpyxl

# %% [markdown]
# # USE ADVI (only 1000 rows for testing):

# %%
import numpy as np
import pandas as pd
import pymc as pm
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, precision_score, recall_score

# %%
# Load dataset
df = pd.read_excel("book_ratings.xlsx")

# Select relevant columns
df = df[['User-ID', 'ISBN', 'Book-Rating']]

# %%
# Drop zero values as they are not the actual rating
df = df[df['Book-Rating'] > 0]

# %%
# Check the size of the data
len(df)
# Out:
# 383840

# %%
df.head()
# Out:
#     User-ID        ISBN  Book-Rating
# 1    276726  0155061224            5
# 3    276729  052165615X            3
# 4    276729  0521795028            6
# 6    276744  038550120X            7
# 13   276747  0060517794            9

# %%
# Create a dataframe grouped by unique users
def create_df_user_reviews(df):
    # Count the number of reviews per user
    user_counts = df['User-ID'].value_counts()
    
    # Store number of reviews per user in a new DataFrame
    df_user_reviews = user_counts.reset_index()
    df_user_reviews.columns = ['User-ID', 'Review-Count']
    
    return df_user_reviews

# %%
df_user_reviews = create_df_user_reviews(df)
df_user_reviews
# Out:
#        User-ID  Review-Count
# 0        11676          6943
# 1        98391          5691
# 2       189835          1899
# 3       153662          1845
# 4        23902          1180
# ...        ...           ...
# 68086   114767             1
# 68087   114771             1
# 68088   114772             1
# 68089   114777             1
# 68090   276721             1
#
# [68091 rows x 2 columns]

# %%
# Create a dataframe with the users that made less then or equal to 20 reviews
def create_df_filtered(df):
    # Count the number of reviews per user
    user_counts = df['User-ID'].value_counts()
    
    # Remove users with 20 or more reviews
    valid_users = user_counts[user_counts >= 2].index
    df_filtered = df[df['User-ID'].isin(valid_users)]
    
    return df_filtered

# %%
df = create_df_filtered(df)
len(df)
# Out:
# 344617

# %%
# **Downsample to 1000 random rows for testing**
df = df.sample(n=1000, random_state=42).reset_index(drop=True)

# %%
df.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0    44852  0440236703            7
# 1   104113  0517061015            7
# 2    86720  0380717581            7
# 3    19371  0446520802            4
# 4   258769  0575075260            8

# %%
train_df.head()
# Out:
#      User-ID        ISBN  Book-Rating  User-Index  Book-Index
# 29     35826  0140317937           10         105          86
# 535    60251  0553107445            5         169         534
# 695   104125  0789723107            7         319         751
# 557   250333  0060194154            4         770          15
# 836    94744  0333918975            2         284         161

# %%
# Encode User-ID and ISBN as categorical for indexing
df['User-Index'] = df['User-ID'].astype("category").cat.codes
df['Book-Index'] = df['ISBN'].astype("category").cat.codes

# **Remap indices to contiguous range** (Fixes the IndexError)
df['User-Index'] = df['User-Index'].astype("category").cat.codes
df['Book-Index'] = df['Book-Index'].astype("category").cat.codes

# %%
# Compute rating counts per user and book
user_rating_counts = df.groupby('User-Index')['Book-Rating'].count()
book_rating_counts = df.groupby('Book-Index')['Book-Rating'].count()

# Avoid division by zero
user_rating_counts[user_rating_counts == 0] = 1
book_rating_counts[book_rating_counts == 0] = 1

# %%
# Train-test split
train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)

# %%
# Convert to numpy arrays for modeling
train_user_ids = train_df['User-Index'].values
test_user_ids = test_df['User-Index'].values
train_book_ids = train_df['Book-Index'].values
test_book_ids = test_df['Book-Index'].values
train_ratings = train_df['Book-Rating'].values # Using raw ratings for Poisson
test_ratings = test_df['Book-Rating'].values

# %%
# Get updated number of unique users and books
num_users = df['User-Index'].nunique()
num_books = df['Book-Index'].nunique()

print("Number of unique users:", num_users)
print("Number of unique books:", num_books)
# Out:
# Number of unique users: 858
# Number of unique books: 972

# %%
# Set latent dimension 
latent_dim = 5

# Bayesian Probabilistic Matrix Factorization Model with Gamma-Poisson
with pm.Model() as model:
    # Prior for global mean rating
    mu = pm.Gamma("mu", alpha=2, beta=0.5)
    
    # ----- User and book bias priors (Adjust sigma for best performance) -----
    user_bias = pm.Normal("user_bias", mu=0, sigma=0.5 / np.sqrt(user_rating_counts + 1), shape=num_users)
    book_bias = pm.Normal("book_bias", mu=0, sigma=0.5 / np.sqrt(book_rating_counts + 1), shape=num_books)

    # Hierarchical priors for latent factors (beta=1 worked best)
    sigma_u = pm.HalfCauchy("sigma_u", beta=1)
    sigma_b = pm.HalfCauchy("sigma_b", beta=1)
    
    user_factors = pm.Normal("user_factors", mu=0, sigma=sigma_u, shape=(num_users, latent_dim))
    book_factors = pm.Normal("book_factors", mu=0, sigma=sigma_b, shape=(num_books, latent_dim))

    # Expected rating using Poisson lambda
    lambda_rating = pm.math.exp(
        mu +
        user_bias[train_user_ids] +
        book_bias[train_book_ids] +
        (user_factors[train_user_ids] * book_factors[train_book_ids]).sum(axis=1)
    )

    # Poisson likelihood
    ratings_obs = pm.Poisson("ratings_obs", mu=lambda_rating, observed=train_ratings)
    
    # Use ADVI for fast variational inference instead of NUTS
    print("Running Variational Inference (ADVI)...")
    approx = pm.fit(n=50000, method="advi")
    trace = approx.sample(draws=2000)

# **Extract posterior values manually since PyMC won't sample `ratings_obs`**
with model:
    print("\nManually Generating Predictions Using Posterior Samples...")
    
    # Extract posterior values
    mu_post = trace.posterior["mu"].mean().item()
    user_bias_post = trace.posterior["user_bias"].mean(dim=("chain", "draw")).values
    book_bias_post = trace.posterior["book_bias"].mean(dim=("chain", "draw")).values
    user_factors_post = trace.posterior["user_factors"].mean(dim=("chain", "draw")).values
    book_factors_post = trace.posterior["book_factors"].mean(dim=("chain", "draw")).values

    # Compute expected ratings
    predicted_ratings = np.exp(
        mu_post + 
        user_bias_post[test_user_ids] + 
        book_bias_post[test_book_ids] +
        (user_factors_post[test_user_ids] * book_factors_post[test_book_ids]).sum(axis=1)
    )

    print("\nExample of Predicted Ratings (posterior predictive mean):")
    print(predicted_ratings[:5])
    
# Evaluation Metrics
mae = mean_absolute_error(test_ratings, predicted_ratings)
rmse = np.sqrt(mean_squared_error(test_ratings, predicted_ratings))

print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
# Out:
# Running Variational Inference (ADVI)...
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Finished [100%]: Average Loss = 2,787
# Manually Generating Predictions Using Posterior Samples...
#
# Example of Predicted Ratings (posterior predictive mean):
# [5.87789129 5.78640202 5.7603901  5.71184689 5.87700667]
# Mean Absolute Error (MAE): 2.2964
# Root Mean Squared Error (RMSE): 2.6153

# %%
# Evaluation Metrics
mae = mean_absolute_error(test_ratings, predicted_ratings)
rmse = np.sqrt(mean_squared_error(test_ratings, predicted_ratings))

print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
# Out:
# Mean Absolute Error (MAE): 2.2964
# Root Mean Squared Error (RMSE): 2.6153

# %%
# Evaluation of Precision, Recall, MAE, and RMSE

def evaluate_predictions(true_ratings, predicted_ratings, threshold=7):
    mae = mean_absolute_error(true_ratings, predicted_ratings)
    rmse = np.sqrt(mean_squared_error(true_ratings, predicted_ratings))
    
    # Convert to binary relevance (1 if rating >= threshold, else 0)
    true_binary = (true_ratings >= threshold).astype(int)
    predicted_binary = (predicted_ratings >= threshold).astype(int)
    
    precision = precision_score(true_binary, predicted_binary, average='micro')
    recall = recall_score(true_binary, predicted_binary, average='micro')
    
    print(f"MAE: {mae:.4f}")
    print(f"RMSE: {rmse:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")

# Running evaluation
predicted_train_ratings = np.exp(
    trace.posterior["mu"].mean().item() +
    trace.posterior["user_bias"].mean(dim=("chain", "draw")).values[train_user_ids] +
    trace.posterior["book_bias"].mean(dim=("chain", "draw")).values[train_book_ids]
)
predicted_test_ratings = np.exp(
    trace.posterior["mu"].mean().item() +
    trace.posterior["user_bias"].mean(dim=("chain", "draw")).values[test_user_ids] +
    trace.posterior["book_bias"].mean(dim=("chain", "draw")).values[test_book_ids]
)

evaluate_predictions(train_ratings, predicted_train_ratings)
evaluate_predictions(test_ratings, predicted_test_ratings)
# Out:
# MAE: 1.3195
# RMSE: 1.4894
# Precision: 0.5850
# Recall: 0.5850
# MAE: 2.2966
# RMSE: 2.6153
# Precision: 0.1950
# Recall: 0.1950

# %%
# ---- Bayes General Multi-Step Lookahead Recommendation ---- #

def bayes_general_recommendation(user_index, book_indices, trace, top_k=5, exploration_factor=0.5, regret_threshold=0.8, max_regret=2.0):
    """
    Multi-step lookahead Bayesian regret minimization for recommending 5 books.
    """
    mu_samples = trace.posterior["mu"].values
    user_bias_samples = trace.posterior["user_bias"].values[:, :, user_index]
    book_bias_samples = trace.posterior["book_bias"].values[:, :, book_indices]
    user_factors_samples = trace.posterior["user_factors"].values[:, :, user_index, :]
    book_factors_samples = trace.posterior["book_factors"].values[:, :, book_indices, :]

    num_samples = mu_samples.shape[1]  # Number of posterior samples
    
    # Compute expected rewards using posterior sampling
    expected_rewards = np.mean(
        np.exp(mu_samples[:, :, None] + user_bias_samples[:, :, None] + book_bias_samples +
               np.sum(user_factors_samples[:, :, None, :] * book_factors_samples, axis=-1)), axis=1
    )

    # Compute variance (uncertainty measure)
    rating_uncertainty = np.var(
        np.exp(mu_samples[:, :, None] + user_bias_samples[:, :, None] + book_bias_samples +
               np.sum(user_factors_samples[:, :, None, :] * book_factors_samples, axis=-1)), axis=1
    )
    
    # Compute Bayesian regret
    best_expected_reward = np.max(expected_rewards, axis=1)
    regrets = best_expected_reward[:, None] - expected_rewards

    # Cap regret to prevent extreme exploration
    regrets = np.clip(regrets, 0, max_regret)

    # Apply regret threshold
    should_explore = regrets > regret_threshold

    # Compute future learning potential
    expected_future_gain = exploration_factor * rating_uncertainty

    # Compute exploration-adjusted score
    exploration_score = expected_rewards + expected_future_gain

    # Rank books
    ranked_books = np.argsort(-exploration_score, axis=1)  # Sort in descending order

    # Select top-k books for recommendation
    selected_books = [book_indices[i] for i in ranked_books[0, :top_k]]

    return selected_books

# Example usage: Recommend 5 books for a user
user_id_example = 42  # Replace with an actual user ID
book_pool = np.arange(num_books)  # Assuming all books are available

recommended_books = bayes_general_recommendation(user_id_example, book_pool, trace, top_k=5)
print("\nTop-5 Recommended Books for User", user_id_example, ":", recommended_books)
# Out:
# Top-5 Recommended Books for User 42 : [12, 386, 60, 242, 926]

# %%
# Evaluation of Precision, Recall, MAE, and RMSE in the top 5 recommendations

def evaluate_recommendations(user_ids, book_pool, trace, test_df, top_k=5, rating_threshold=1):
    total_precision = 0
    total_recall = 0
    total_mae = 0
    total_rmse = 0
    user_count = 0

    for user in user_ids:
        # Get actual books the user has rated in the test set
        user_ratings = test_df[test_df['User-Index'] == user]
        
        # Filter books with ratings above threshold (considered "relevant")
        actual_books = set(user_ratings[user_ratings['Book-Rating'] >= rating_threshold]['Book-Index'].values)
        actual_ratings = user_ratings[user_ratings['Book-Index'].isin(actual_books)]['Book-Rating'].values

        # Get top-k recommended books
        recommended_books = set(bayes_general_recommendation(user, book_pool, trace, top_k))

        # Ensure proper indexing and matching
        correct_matches = recommended_books & actual_books

        print(f"User {user} - Actual Books: {actual_books}")
        print(f"User {user} - Recommended Books: {recommended_books}")
        print(f"Correct Matches: {correct_matches}\n")

        # If there are no actual relevant books, we cannot compute recall
        if len(actual_books) == 0:
            continue  # Skip users with no actual relevant books

        # Precision@K: Fraction of recommended books that are actually relevant
        precision = len(correct_matches) / top_k

        # Recall@K: Fraction of relevant books that were successfully recommended
        recall = len(correct_matches) / len(actual_books)

        # Predict ratings for actual books
        predicted_ratings = np.array([
            trace.posterior["mu"].mean().item() +
            trace.posterior["user_bias"].mean(dim=("chain", "draw")).values[user] +
            trace.posterior["book_bias"].mean(dim=("chain", "draw")).values[book]
            for book in actual_books
        ])

       # Compute MAE and RMSE only if there are matching predictions
        if len(actual_ratings) > 0 and len(predicted_ratings) > 0:
            mae = mean_absolute_error(actual_ratings, predicted_ratings)
            rmse = np.sqrt(mean_squared_error(actual_ratings, predicted_ratings))
        else:
            mae, rmse = 0, 0

        total_precision += precision
        total_recall += recall
        total_mae += mae
        total_rmse += rmse
        user_count += 1
    
    # Compute average metrics across users
    avg_precision = total_precision / user_count if user_count > 0 else 0
    avg_recall = total_recall / user_count if user_count > 0 else 0
    avg_mae = total_mae / user_count if user_count > 0 else 0
    avg_rmse = total_rmse / user_count if user_count > 0 else 0
    
    print(f"Average Precision@{top_k}: {avg_precision:.4f}")
    print(f"Average Recall@{top_k}: {avg_recall:.4f}")
    print(f"Mean Absolute Error (MAE): {avg_mae:.4f}")
    print(f"Root Mean Squared Error (RMSE): {avg_rmse:.4f}")

# Running evaluation
book_pool = np.arange(num_books)
evaluate_recommendations(test_user_ids, book_pool, trace, test_df, top_k=5)
# Out:
# User 471 - Actual Books: {362}
# User 471 - Recommended Books: {386, 55, 439, 761, 122}
# Correct Matches: set()
#
# User 320 - Actual Books: {742}
# User 320 - Recommended Books: {164, 324, 911, 793, 732}
# Correct Matches: set()
#
# User 327 - Actual Books: {169}
# User 327 - Recommended Books: {742, 74, 882, 949, 476}
# Correct Matches: set()
#
# User 9 - Actual Books: {876}
# User 9 - Recommended Books: {164, 806, 654, 47, 732}
# Correct Matches: set()
#
# User 192 - Actual Books: {121}
# User 192 - Recommended Books: {577, 709, 613, 124, 701}
# Correct Matches: set()
#
# User 795 - Actual Books: {811}
# User 795 - Recommended Books: {964, 207, 15, 306, 509}
# Correct Matches: set()
#
# User 200 - Actual Books: {897}
# User 200 - Recommended Books: {867, 41, 73, 601, 827}
# Correct Matches: set()
#
# User 569 - Actual Books: {213}
# User 569 - Recommended Books: {96, 897, 103, 158, 607}
# Correct Matches: set()
#
# User 213 - Actual Books: {686}
# User 213 - Recommended Books: {135, 941, 625, 700, 221}
# Correct Matches: set()
#
# User 533 - Actual Books: {786, 59}
# User 533 - Recommended Books: {835, 429, 847, 568, 574}
# Correct Matches: set()
#
# User 324 - Actual Books: {372}
# User 324 - Recommended Books: {330, 460, 849, 565, 509}
# Correct Matches: set()
#
# User 658 - Actual Books: {719}
# User 658 - Recommended Books: {68, 201, 170, 565, 55}
# Correct Matches: set()
#
# User 669 - Actual Books: {601, 610}
# User 669 - Recommended Books: {32, 207, 495, 214, 863}
# Correct Matches: set()
#
# User 296 - Actual Books: {25, 721, 598, 703}
# User 296 - Recommended Books: {482, 357, 207, 250, 92}
# Correct Matches: set()
#
# User 536 - Actual Books: {575}
# User 536 - Recommended Books: {228, 134, 135, 60, 829}
# Correct Matches: set()
#
# User 424 - Actual Books: {103}
# User 424 - Recommended Books: {833, 786, 242, 858, 509}
# Correct Matches: set()
#
# User 724 - Actual Books: {436}
# User 724 - Recommended Books: {160, 193, 867, 40, 639}
# Correct Matches: set()
#
# User 667 - Actual Books: {164}
# User 667 - Recommended Books: {300, 694, 410, 893, 413}
# Correct Matches: set()
#
# User 283 - Actual Books: {134}
# User 283 - Recommended Books: {709, 72, 202, 56, 285}
# Correct Matches: set()
#
# User 522 - Actual Books: {953}
# User 522 - Recommended Books: {330, 271, 784, 219, 60}
# Correct Matches: set()
#
# User 163 - Actual Books: {565}
# User 163 - Recommended Books: {391, 136, 265, 362, 375}
# Correct Matches: set()
#
# User 421 - Actual Books: {893}
# User 421 - Recommended Books: {68, 294, 551, 891, 223}
# Correct Matches: set()
#
# User 222 - Actual Books: {136}
# User 222 - Recommended Books: {130, 305, 209, 21, 891}
# Correct Matches: set()
#
# User 107 - Actual Books: {619}
# User 107 - Recommended Books: {69, 957, 338, 789, 829}
# Correct Matches: set()
#
# User 722 - Actual Books: {26}
# User 722 - Recommended Books: {429, 599, 410, 573, 639}
# Correct Matches: set()
#
# User 789 - Actual Books: {250}
# User 789 - Recommended Books: {137, 881, 786, 338, 790}
# Correct Matches: set()
#
# User 509 - Actual Books: {302}
# User 509 - Recommended Books: {228, 68, 695, 696, 255}
# Correct Matches: set()
#
# User 590 - Actual Books: {28}
# User 590 - Recommended Books: {672, 738, 362, 436, 858}
# Correct Matches: set()
#
# User 553 - Actual Books: {551}
# User 553 - Recommended Books: {654, 793, 571, 573, 926}
# Correct Matches: set()
#
# User 279 - Actual Books: {849}
# User 279 - Recommended Books: {900, 228, 330, 859, 286}
# Correct Matches: set()
#
# User 628 - Actual Books: {73}
# User 628 - Recommended Books: {517, 718, 944, 691, 441}
# Correct Matches: set()
#
# User 839 - Actual Books: {700}
# User 839 - Recommended Books: {201, 73, 401, 504, 863}
# Correct Matches: set()
#
# User 67 - Actual Books: {150}
# User 67 - Recommended Books: {867, 518, 661, 695, 122}
# Correct Matches: set()
#
# User 272 - Actual Books: {271}
# User 272 - Recommended Books: {35, 913, 55, 600, 668}
# Correct Matches: set()
#
# User 392 - Actual Books: {252}
# User 392 - Recommended Books: {192, 900, 42, 761, 26}
# Correct Matches: set()
#
# User 374 - Actual Books: {592}
# User 374 - Recommended Books: {901, 742, 103, 744, 223}
# Correct Matches: set()
#
# User 170 - Actual Books: {56}
# User 170 - Recommended Books: {804, 715, 505, 47, 601}
# Correct Matches: set()
#
# User 288 - Actual Books: {128}
# User 288 - Recommended Books: {324, 274, 250, 573, 703}
# Correct Matches: set()
#
# User 669 - Actual Books: {601, 610}
# User 669 - Recommended Books: {32, 207, 495, 214, 863}
# Correct Matches: set()
#
# User 80 - Actual Books: {272}
# User 80 - Recommended Books: {709, 426, 170, 220, 509}
# Correct Matches: set()
#
# User 744 - Actual Books: {727}
# User 744 - Recommended Books: {42, 909, 275, 695, 732}
# Correct Matches: set()
#
# User 122 - Actual Books: {42}
# User 122 - Recommended Books: {357, 881, 626, 20, 565}
# Correct Matches: set()
#
# User 40 - Actual Books: {386}
# User 40 - Recommended Books: {455, 941, 909, 881, 861}
# Correct Matches: set()
#
# User 632 - Actual Books: {860}
# User 632 - Recommended Books: {294, 455, 271, 733, 639}
# Correct Matches: set()
#
# User 573 - Actual Books: {203}
# User 573 - Recommended Books: {134, 849, 274, 281, 860}
# Correct Matches: set()
#
# User 109 - Actual Books: {265}
# User 109 - Recommended Books: {644, 816, 435, 695, 92}
# Correct Matches: set()
#
# User 56 - Actual Books: {912}
# User 56 - Recommended Books: {549, 639, 22, 861, 607}
# Correct Matches: set()
#
# User 747 - Actual Books: {613}
# User 747 - Recommended Books: {931, 806, 73, 429, 573}
# Correct Matches: set()
#
# User 63 - Actual Books: {761}
# User 63 - Recommended Books: {900, 264, 213, 696, 29}
# Correct Matches: set()
#
# User 578 - Actual Books: {429}
# User 578 - Recommended Books: {357, 715, 238, 217, 158}
# Correct Matches: set()
#
# User 25 - Actual Books: {294}
# User 25 - Recommended Books: {160, 742, 811, 55, 314}
# Correct Matches: set()
#
# User 760 - Actual Books: {92}
# User 760 - Recommended Books: {909, 654, 689, 662, 697}
# Correct Matches: set()
#
# User 621 - Actual Books: {76}
# User 621 - Recommended Books: {3, 851, 436, 890, 540}
# Correct Matches: set()
#
# User 504 - Actual Books: {652}
# User 504 - Recommended Books: {573, 233, 811, 285, 158}
# Correct Matches: set()
#
# User 532 - Actual Books: {146}
# User 532 - Recommended Books: {709, 357, 844, 437, 760}
# Correct Matches: set()
#
# User 46 - Actual Books: {381}
# User 46 - Recommended Books: {132, 508, 274, 538, 220}
# Correct Matches: set()
#
# User 589 - Actual Books: {651}
# User 589 - Recommended Books: {610, 711, 60, 858, 732}
# Correct Matches: set()
#
# User 132 - Actual Books: {217}
# User 132 - Recommended Books: {391, 43, 528, 213, 703}
# Correct Matches: set()
#
# User 818 - Actual Books: {711}
# User 818 - Recommended Books: {930, 170, 213, 60, 573}
# Correct Matches: set()
#
# User 375 - Actual Books: {55}
# User 375 - Recommended Books: {289, 963, 784, 882, 573}
# Correct Matches: set()
#
# User 767 - Actual Books: {482, 855}
# User 767 - Recommended Books: {897, 242, 915, 381, 573}
# Correct Matches: set()
#
# User 505 - Actual Books: {964}
# User 505 - Recommended Books: {610, 932, 274, 121, 92}
# Correct Matches: set()
#
# User 785 - Actual Books: {385}
# User 785 - Recommended Books: {489, 909, 242, 22, 702}
# Correct Matches: set()
#
# User 256 - Actual Books: {639}
# User 256 - Recommended Books: {897, 505, 919, 281, 286}
# Correct Matches: set()
#
# User 855 - Actual Books: {625}
# User 855 - Recommended Books: {265, 202, 120, 92, 351}
# Correct Matches: set()
#
# User 296 - Actual Books: {25, 721, 598, 703}
# User 296 - Recommended Books: {482, 357, 207, 250, 92}
# Correct Matches: set()
#
# User 161 - Actual Books: {858}
# User 161 - Recommended Books: {386, 870, 496, 913, 662}
# Correct Matches: set()
#
# User 150 - Actual Books: {111}
# User 150 - Recommended Books: {228, 151, 281, 410, 540}
# Correct Matches: set()
#
# User 140 - Actual Books: {701}
# User 140 - Recommended Books: {448, 32, 855, 55, 60}
# Correct Matches: set()
#
# User 295 - Actual Books: {158}
# User 295 - Recommended Books: {228, 900, 971, 461, 695}
# Correct Matches: set()
#
# User 787 - Actual Books: {320}
# User 787 - Recommended Books: {865, 866, 281, 338, 697}
# Correct Matches: set()
#
# User 612 - Actual Books: {833}
# User 612 - Recommended Books: {233, 274, 276, 853, 122}
# Correct Matches: set()
#
# User 176 - Actual Books: {827}
# User 176 - Recommended Books: {294, 428, 844, 274, 439}
# Correct Matches: set()
#
# User 533 - Actual Books: {786, 59}
# User 533 - Recommended Books: {835, 429, 847, 568, 574}
# Correct Matches: set()
#
# User 45 - Actual Books: {870, 622}
# User 45 - Recommended Books: {130, 228, 870, 7, 436}
# Correct Matches: {870}
#
# User 729 - Actual Books: {903}
# User 729 - Recommended Books: {801, 727, 504, 410, 732}
# Correct Matches: set()
#
# User 419 - Actual Books: {28}
# User 419 - Recommended Books: {385, 613, 13, 158, 702}
# Correct Matches: set()
#
# User 297 - Actual Books: {220}
# User 297 - Recommended Books: {931, 299, 491, 21, 223}
# Correct Matches: set()
#
# User 178 - Actual Books: {224}
# User 178 - Recommended Books: {224, 613, 654, 821, 565}
# Correct Matches: {224}
#
# User 643 - Actual Books: {504}
# User 643 - Recommended Books: {865, 499, 120, 185, 250}
# Correct Matches: set()
#
# User 227 - Actual Books: {43}
# User 227 - Recommended Books: {226, 744, 619, 143, 415}
# Correct Matches: set()
#
# User 850 - Actual Books: {391}
# User 850 - Recommended Books: {160, 754, 274, 121, 639}
# Correct Matches: set()
#
# User 520 - Actual Books: {29}
# User 520 - Recommended Books: {565, 342, 250, 891, 61}
# Correct Matches: set()
#
# User 416 - Actual Books: {49}
# User 416 - Recommended Books: {577, 482, 935, 143, 250}
# Correct Matches: set()
#
# User 385 - Actual Books: {314}
# User 385 - Recommended Books: {711, 202, 913, 49, 953}
# Correct Matches: set()
#
# User 742 - Actual Books: {311}
# User 742 - Recommended Books: {576, 930, 242, 22, 316}
# Correct Matches: set()
#
# User 199 - Actual Books: {810}
# User 199 - Recommended Books: {386, 483, 651, 941, 654}
# Correct Matches: set()
#
# User 97 - Actual Books: {489}
# User 97 - Recommended Books: {135, 136, 686, 565, 25}
# Correct Matches: set()
#
# User 821 - Actual Books: {697}
# User 821 - Recommended Books: {738, 330, 811, 630, 55}
# Correct Matches: set()
#
# User 488 - Actual Books: {607}
# User 488 - Recommended Books: {386, 233, 496, 22, 191}
# Correct Matches: set()
#
# User 535 - Actual Books: {509}
# User 535 - Recommended Books: {103, 72, 697, 59, 252}
# Correct Matches: set()
#
# User 389 - Actual Books: {358}
# User 389 - Recommended Books: {833, 357, 592, 626, 703}
# Correct Matches: set()
#
# User 27 - Actual Books: {282}
# User 27 - Recommended Books: {7, 74, 28, 476, 575}
# Correct Matches: set()
#
# User 420 - Actual Books: {790}
# User 420 - Recommended Books: {164, 646, 203, 250, 573}
# Correct Matches: set()
#
# User 675 - Actual Books: {891}
# User 675 - Recommended Books: {577, 75, 213, 22, 855}
# Correct Matches: set()
#
# User 94 - Actual Books: {476}
# User 94 - Recommended Books: {455, 811, 815, 858, 540}
# Correct Matches: set()
#
# User 608 - Actual Books: {784}
# User 608 - Recommended Books: {650, 268, 471, 504, 476}
# Correct Matches: set()
#
# User 539 - Actual Books: {147}
# User 539 - Recommended Books: {64, 713, 970, 274, 158}
# Correct Matches: set()
#
# User 290 - Actual Books: {836}
# User 290 - Recommended Books: {358, 429, 950, 408, 703}
# Correct Matches: set()
#
# User 45 - Actual Books: {870, 622}
# User 45 - Recommended Books: {130, 228, 870, 7, 436}
# Correct Matches: {870}
#
# User 447 - Actual Books: {909}
# User 447 - Recommended Books: {66, 104, 300, 82, 700}
# Correct Matches: set()
#
# User 629 - Actual Books: {881}
# User 629 - Recommended Books: {74, 459, 176, 436, 88}
# Correct Matches: set()
#
# User 642 - Actual Books: {505}
# User 642 - Recommended Books: {358, 722, 436, 217, 573}
# Correct Matches: set()
#
# User 87 - Actual Books: {324}
# User 87 - Recommended Books: {291, 644, 518, 138, 342}
# Correct Matches: set()
#
# User 280 - Actual Books: {242}
# User 280 - Recommended Books: {584, 300, 876, 697, 666}
# Correct Matches: set()
#
# User 390 - Actual Books: {867}
# User 390 - Recommended Books: {43, 844, 173, 113, 598}
# Correct Matches: set()
#
# User 767 - Actual Books: {482, 855}
# User 767 - Recommended Books: {897, 242, 915, 381, 573}
# Correct Matches: set()
#
# User 525 - Actual Books: {577}
# User 525 - Recommended Books: {932, 806, 816, 786, 598}
# Correct Matches: set()
#
# User 73 - Actual Books: {497}
# User 73 - Recommended Books: {802, 299, 686, 504, 699}
# Correct Matches: set()
#
# User 303 - Actual Books: {201}
# User 303 - Recommended Books: {207, 913, 721, 213, 250}
# Correct Matches: set()
#
# User 528 - Actual Books: {644, 815}
# User 528 - Recommended Books: {96, 302, 852, 697, 891}
# Correct Matches: set()
#
# User 286 - Actual Books: {470}
# User 286 - Recommended Books: {644, 47, 19, 51, 250}
# Correct Matches: set()
#
# User 193 - Actual Books: {122}
# User 193 - Recommended Books: {833, 357, 913, 628, 695}
# Correct Matches: set()
#
# User 69 - Actual Books: {410}
# User 69 - Recommended Books: {132, 742, 73, 722, 250}
# Correct Matches: set()
#
# User 852 - Actual Books: {941}
# User 852 - Recommended Books: {866, 300, 52, 891, 509}
# Correct Matches: set()
#
# User 484 - Actual Books: {32}
# User 484 - Recommended Books: {160, 68, 650, 861, 639}
# Correct Matches: set()
#
# User 649 - Actual Books: {312}
# User 649 - Recommended Books: {897, 644, 719, 410, 223}
# Correct Matches: set()
#
# User 265 - Actual Books: {793}
# User 265 - Recommended Books: {294, 271, 143, 600, 57}
# Correct Matches: set()
#
# User 70 - Actual Books: {63}
# User 70 - Recommended Books: {357, 426, 686, 913, 434}
# Correct Matches: set()
#
# User 586 - Actual Books: {866}
# User 586 - Recommended Books: {480, 930, 869, 424, 274}
# Correct Matches: set()
#
# User 237 - Actual Books: {448}
# User 237 - Recommended Books: {545, 274, 311, 121, 92}
# Correct Matches: set()
#
# User 111 - Actual Books: {926}
# User 111 - Recommended Books: {483, 679, 722, 694, 348}
# Correct Matches: set()
#
# User 582 - Actual Books: {709}
# User 582 - Recommended Books: {26, 358, 362, 410, 282}
# Correct Matches: set()
#
# User 430 - Actual Books: {662}
# User 430 - Recommended Books: {930, 389, 838, 711, 476}
# Correct Matches: set()
#
# User 647 - Actual Books: {357}
# User 647 - Recommended Books: {385, 35, 489, 591, 592}
# Correct Matches: set()
#
# User 242 - Actual Books: {573}
# User 242 - Recommended Books: {160, 7, 600, 697, 219}
# Correct Matches: set()
#
# User 660 - Actual Books: {971}
# User 660 - Recommended Books: {289, 103, 429, 722, 286}
# Correct Matches: set()
#
# User 689 - Actual Books: {200}
# User 689 - Recommended Books: {870, 685, 622, 941, 754}
# Correct Matches: set()
#
# User 377 - Actual Books: {915}
# User 377 - Recommended Books: {426, 844, 721, 722, 695}
# Correct Matches: set()
#
# User 413 - Actual Books: {527}
# User 413 - Recommended Books: {128, 867, 788, 821, 699}
# Correct Matches: set()
#
# User 184 - Actual Books: {4}
# User 184 - Recommended Books: {772, 913, 499, 310, 703}
# Correct Matches: set()
#
# User 697 - Actual Books: {330}
# User 697 - Recommended Books: {388, 294, 276, 92, 191}
# Correct Matches: set()
#
# User 761 - Actual Books: {306}
# User 761 - Recommended Books: {66, 47, 116, 601, 410}
# Correct Matches: set()
#
# User 315 - Actual Books: {413}
# User 315 - Recommended Books: {32, 711, 311, 603, 254}
# Correct Matches: set()
#
# User 356 - Actual Books: {696}
# User 356 - Recommended Books: {192, 357, 44, 207, 158}
# Correct Matches: set()
#
# User 147 - Actual Books: {202}
# User 147 - Recommended Books: {357, 242, 470, 439, 761}
# Correct Matches: set()
#
# User 298 - Actual Books: {19}
# User 298 - Recommended Books: {291, 936, 272, 855, 26}
# Correct Matches: set()
#
# User 567 - Actual Books: {732}
# User 567 - Recommended Books: {786, 118, 250, 891, 60}
# Correct Matches: set()
#
# User 398 - Actual Books: {191}
# User 398 - Recommended Books: {5, 357, 56, 603, 863}
# Correct Matches: set()
#
# User 336 - Actual Books: {338}
# User 336 - Recommended Books: {897, 163, 264, 953, 861}
# Correct Matches: set()
#
# User 730 - Actual Books: {754}
# User 730 - Recommended Books: {865, 170, 913, 217, 734}
# Correct Matches: set()
#
# User 483 - Actual Books: {899}
# User 483 - Recommended Books: {160, 687, 785, 626, 26}
# Correct Matches: set()
#
# User 501 - Actual Books: {744}
# User 501 - Recommended Books: {881, 853, 59, 92, 254}
# Correct Matches: set()
#
# User 549 - Actual Books: {434}
# User 549 - Recommended Books: {833, 272, 790, 121, 252}
# Correct Matches: set()
#
# User 765 - Actual Books: {51}
# User 765 - Recommended Books: {694, 855, 699, 668, 861}
# Correct Matches: set()
#
# User 364 - Actual Books: {738}
# User 364 - Recommended Books: {551, 744, 811, 844, 111}
# Correct Matches: set()
#
# User 296 - Actual Books: {25, 721, 598, 703}
# User 296 - Recommended Books: {482, 357, 207, 250, 92}
# Correct Matches: set()
#
# User 245 - Actual Books: {865}
# User 245 - Recommended Books: {903, 618, 694, 697, 858}
# Correct Matches: set()
#
# User 699 - Actual Books: {160}
# User 699 - Recommended Books: {358, 144, 849, 338, 732}
# Correct Matches: set()
#
# User 266 - Actual Books: {14}
# User 266 - Recommended Books: {737, 217, 334, 761, 25}
# Correct Matches: set()
#
# User 425 - Actual Books: {863}
# User 425 - Recommended Books: {674, 419, 811, 971, 335}
# Correct Matches: set()
#
# User 84 - Actual Books: {806}
# User 84 - Recommended Books: {160, 523, 913, 124, 223}
# Correct Matches: set()
#
# User 296 - Actual Books: {25, 721, 598, 703}
# User 296 - Recommended Books: {482, 357, 207, 250, 92}
# Correct Matches: set()
#
# User 240 - Actual Books: {816}
# User 240 - Recommended Books: {810, 22, 87, 859, 414}
# Correct Matches: set()
#
# User 725 - Actual Books: {626}
# User 725 - Recommended Books: {806, 912, 849, 370, 791}
# Correct Matches: set()
#
# User 705 - Actual Books: {207}
# User 705 - Recommended Books: {170, 811, 913, 821, 793}
# Correct Matches: set()
#
# User 528 - Actual Books: {644, 815}
# User 528 - Recommended Books: {96, 302, 852, 697, 891}
# Correct Matches: set()
#
# User 817 - Actual Books: {170}
# User 817 - Recommended Books: {930, 482, 581, 969, 607}
# Correct Matches: set()
#
# User 44 - Actual Books: {13}
# User 44 - Recommended Books: {963, 810, 19, 184, 703}
# Correct Matches: set()
#
# User 540 - Actual Books: {60}
# User 540 - Recommended Books: {651, 639, 786, 793, 57}
# Correct Matches: set()
#
# User 779 - Actual Books: {47}
# User 779 - Recommended Books: {320, 744, 785, 825, 381}
# Correct Matches: set()
#
# User 837 - Actual Books: {603}
# User 837 - Recommended Books: {223, 228, 721, 350, 607}
# Correct Matches: set()
#
# User 190 - Actual Books: {233}
# User 190 - Recommended Books: {33, 809, 846, 19, 342}
# Correct Matches: set()
#
# User 48 - Actual Books: {591}
# User 48 - Recommended Books: {34, 73, 362, 789, 509}
# Correct Matches: set()
#
# User 293 - Actual Books: {752}
# User 293 - Recommended Books: {324, 686, 434, 600, 223}
# Correct Matches: set()
#
# User 551 - Actual Books: {274}
# User 551 - Recommended Books: {65, 654, 47, 470, 695}
# Correct Matches: set()
#
# User 82 - Actual Books: {370}
# User 82 - Recommended Books: {68, 179, 793, 28, 412}
# Correct Matches: set()
#
# User 254 - Actual Books: {930}
# User 254 - Recommended Books: {357, 136, 426, 651, 786}
# Correct Matches: set()
#
# User 92 - Actual Books: {68}
# User 92 - Recommended Books: {833, 866, 391, 203, 59}
# Correct Matches: set()
#
# User 372 - Actual Books: {439}
# User 372 - Recommended Books: {897, 3, 228, 498, 862}
# Correct Matches: set()
#
# User 418 - Actual Books: {518}
# User 418 - Recommended Books: {291, 876, 816, 821, 92}
# Correct Matches: set()
#
# User 620 - Actual Books: {96}
# User 620 - Recommended Books: {801, 42, 429, 109, 17}
# Correct Matches: set()
#
# User 771 - Actual Books: {654}
# User 771 - Recommended Books: {290, 76, 785, 563, 699}
# Correct Matches: set()
#
# User 12 - Actual Books: {33}
# User 12 - Recommended Books: {867, 806, 328, 847, 274}
# Correct Matches: set()
#
# User 493 - Actual Books: {861}
# User 493 - Recommended Books: {97, 738, 903, 654, 891}
# Correct Matches: set()
#
# User 814 - Actual Books: {785}
# User 814 - Recommended Books: {128, 203, 44, 306, 29}
# Correct Matches: set()
#
# User 218 - Actual Books: {499}
# User 218 - Recommended Books: {592, 849, 565, 598, 92}
# Correct Matches: set()
#
# User 241 - Actual Books: {829}
# User 241 - Recommended Books: {897, 821, 565, 696, 891}
# Correct Matches: set()
#
# User 220 - Actual Books: {760}
# User 220 - Recommended Books: {964, 42, 793, 59, 926}
# Correct Matches: set()
#
# User 552 - Actual Books: {668}
# User 552 - Recommended Books: {357, 111, 722, 890, 223}
# Correct Matches: set()
#
# User 116 - Actual Books: {44}
# User 116 - Recommended Books: {741, 393, 881, 213, 637}
# Correct Matches: set()
#
# User 763 - Actual Books: {286}
# User 763 - Recommended Books: {577, 642, 518, 849, 59}
# Correct Matches: set()
#
# User 1 - Actual Books: {223}
# User 1 - Recommended Books: {711, 744, 44, 725, 508}
# Correct Matches: set()
#
# User 701 - Actual Books: {7}
# User 701 - Recommended Books: {224, 518, 358, 300, 860}
# Correct Matches: set()
#
# User 180 - Actual Books: {255}
# User 180 - Recommended Books: {44, 816, 147, 699, 60}
# Correct Matches: set()
#
# User 715 - Actual Books: {135}
# User 715 - Recommended Books: {833, 709, 207, 344, 859}
# Correct Matches: set()
#
# User 476 - Actual Books: {426}
# User 476 - Recommended Books: {47, 564, 314, 219, 861}
# Correct Matches: set()
#
# User 756 - Actual Books: {53}
# User 756 - Recommended Books: {870, 458, 202, 719, 601}
# Correct Matches: set()
#
# User 28 - Actual Books: {695}
# User 28 - Recommended Books: {132, 228, 4, 299, 438}
# Correct Matches: set()
#
# User 123 - Actual Books: {124}
# User 123 - Recommended Books: {742, 265, 557, 250, 31}
# Correct Matches: set()
#
# User 614 - Actual Books: {913}
# User 614 - Recommended Books: {68, 651, 790, 281, 926}
# Correct Matches: set()
#
# User 459 - Actual Books: {859}
# User 459 - Recommended Books: {866, 130, 73, 170, 876}
# Correct Matches: set()
#
# User 600 - Actual Books: {699}
# User 600 - Recommended Books: {784, 272, 156, 752, 476}
# Correct Matches: set()
#
# User 225 - Actual Books: {281}
# User 225 - Recommended Books: {709, 294, 680, 816, 51}
# Correct Matches: set()
#
# User 90 - Actual Books: {540}
# User 90 - Recommended Books: {448, 833, 867, 429, 727}
# Correct Matches: set()
#
# User 66 - Actual Books: {374}
# User 66 - Recommended Books: {76, 849, 793, 536, 505}
# Correct Matches: set()
#
# User 351 - Actual Books: {260}
# User 351 - Recommended Books: {386, 163, 492, 855, 29}
# Correct Matches: set()
#
# User 376 - Actual Books: {70}
# User 376 - Recommended Books: {353, 201, 786, 949, 412}
# Correct Matches: set()
#
# User 236 - Actual Books: {291}
# User 236 - Recommended Books: {224, 203, 715, 274, 638}
# Correct Matches: set()
#
# User 461 - Actual Books: {300}
# User 461 - Recommended Books: {327, 233, 74, 881, 957}
# Correct Matches: set()
#
# Average Precision@5: 0.0030
# Average Recall@5: 0.0100
# Mean Absolute Error (MAE): 6.0586
# Root Mean Squared Error (RMSE): 6.0685

# %% [markdown]
# #### Map the recommended books to the book metadata

# %%
# Create a dictionary mapping Book-Index to ISBN
book_index_to_isbn = df.set_index('Book-Index')['ISBN'].to_dict()

# Example recommended books
recommended_books = [644, 28, 785, 250, 900]  # Replace with actual recommended books output

# Map Book-Index to ISBN
recommended_isbns = [book_index_to_isbn[idx] for idx in recommended_books if idx in book_index_to_isbn]

# Print the results
print("\nTop-5 Recommended Books (ISBNs):", recommended_isbns)
# Out:
# Top-5 Recommended Books (ISBNs): ['0671827138', '0060915544', '0836228995', '0375727086', '1594141819']

# %%
import xarray as xr

# Get all user indices
all_users = df['User-Index'].unique()

# Create an empty dictionary to store recommendations
recommendations = {}

# Iterate through each user and get book recommendations
for user_id in all_users:
    recommended_books = bayes_general_recommendation(user_id, np.arange(num_books), trace, top_k=5)
    recommendations[user_id] = recommended_books

# Convert to DataFrame
rec_df = pd.DataFrame.from_dict(recommendations, orient='index', columns=[f'Rec_{i+1}' for i in range(5)])

# Reset index for merging
rec_df.reset_index(inplace=True)
rec_df.rename(columns={'index': 'User-Index'}, inplace=True)

# Merge with the original dataframe on "User-Index"
df_combined = df.merge(rec_df, on='User-Index', how='left')

# Convert the dataframe to xarray Dataset for NetCDF format
ds = xr.Dataset.from_dataframe(df_combined)

# Save as a .nc file
ds.to_netcdf("book_recommendations.nc")

print("✅ Recommendation data saved as 'book_recommendations.nc'")
# Out:
# ✅ Recommendation data saved as 'book_recommendations.nc'

# %%
# Convert the dataset back to a DataFrame for easy previewing
df_preview = ds.to_dataframe()

# Display first few rows
print(df_preview.head())
# Out:
#        User-ID        ISBN  Book-Rating  User-Index  Book-Index  Rec_1  Rec_2  \
# index
# 0        44852  0440236703            7         131         398    790     21
# 1       104113  0517061015            7         318         522    314      7
# 2        86720  0380717581            7         250         259    307    761
# 3        19371  0446520802            4          54         432    260    855
# 4       258769  0575075260            8         800         582    282    895
#
#        Rec_3  Rec_4  Rec_5
# index
# 0        909    613    611
# 1        946    865    517
# 2        499    242    137
# 3        533    897    699
# 4        501    790     13

# %%
# Create a mapping dictionary of Book-Index to ISBN
book_index_to_isbn = df_combined[['Book-Index', 'ISBN']].drop_duplicates().set_index('Book-Index').sort_index()

# Book index & ISBN
print(book_index_to_isbn.head())

# Convert the dataframe to xarray Dataset for NetCDF format
ds = xr.Dataset.from_dataframe(df_combined)

# Save as a .nc file
ds.to_netcdf("book_info.nc")

print("✅ Recommendation data saved as 'book_info.nc'")
# Out:
#                   ISBN
# Book-Index
# 0           0002252341
# 1           0003700933
# 2           0006384684
# 3           0006550789
# 4           0007105665
# ✅ Recommendation data saved as 'book_info.nc'
